# %%
# %sql
CREATE CATALOG IF NOT EXISTS olist_dataset

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS olist_dataset.bronze;
CREATE SCHEMA IF NOT EXISTS olist_dataset.silver;
CREATE SCHEMA IF NOT EXISTS olist_dataset.gold;
CREATE SCHEMA IF NOT EXISTS olist_dataset.source_data;

# %%
# %sql
SHOW DATABASES FROM olist_dataset
